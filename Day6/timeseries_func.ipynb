# %%
import pandas as pd
import numpy as np

# %%
np.random.seed(seed=42)
df = pd.DataFrame(data=np.random.normal(loc=70, scale=10, size=(7,3)),
                  columns=('San Francisco', 'San Diego', 'Los Angeles'),
                  index=['Monday', 'Tuesday', 'Wednesday', 'Thursday', 'Friday', 'Saturday', 'Sunday']
                 )
df = df.round()
df
# Out:
#            San Francisco  San Diego  Los Angeles
# Monday              75.0       69.0         76.0
# Tuesday             85.0       68.0         68.0
# Wednesday           86.0       78.0         65.0
# Thursday            75.0       65.0         65.0
# Friday              72.0       51.0         53.0
# Saturday            64.0       60.0         73.0
# Sunday              61.0       56.0         85.0

# %%
df.diff()
# Out:
#            San Francisco  San Diego  Los Angeles
# Monday               NaN        NaN          NaN
# Tuesday             10.0       -1.0         -8.0
# Wednesday            1.0       10.0         -3.0
# Thursday           -11.0      -13.0          0.0
# Friday              -3.0      -14.0        -12.0
# Saturday            -8.0        9.0         20.0
# Sunday              -3.0       -4.0         12.0

# %%
df.diff(periods=3)
# Out:
#            San Francisco  San Diego  Los Angeles
# Monday               NaN        NaN          NaN
# Tuesday              NaN        NaN          NaN
# Wednesday            NaN        NaN          NaN
# Thursday             0.0       -4.0        -11.0
# Friday             -13.0      -17.0        -15.0
# Saturday           -22.0      -18.0          8.0
# Sunday             -14.0       -9.0         20.0

# %%
df.diff(periods=1, axis=1)
# Out:
#            San Francisco  San Diego  Los Angeles
# Monday               NaN       -6.0          7.0
# Tuesday              NaN      -17.0          0.0
# Wednesday            NaN       -8.0        -13.0
# Thursday             NaN      -10.0          0.0
# Friday               NaN      -21.0          2.0
# Saturday             NaN       -4.0         13.0
# Sunday               NaN       -5.0         29.0

# %%
asfreq_df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2020-01-01", "2020-01-05"))
asfreq_df
# Out:
#             Col1  Col2  Col3
# 2020-01-01    10    13    17
# 2020-01-02    20    23    27
# 2020-01-03    15    18    22
# 2020-01-04    30    33    37
# 2020-01-05    45    48    52

# %%
asfreq_df.asfreq('10T')
# Out:
#                      Col1  Col2  Col3
# 2020-01-01 00:00:00  10.0  13.0  17.0
# 2020-01-01 00:10:00   NaN   NaN   NaN
# 2020-01-01 00:20:00   NaN   NaN   NaN
# 2020-01-01 00:30:00   NaN   NaN   NaN
# 2020-01-01 00:40:00   NaN   NaN   NaN
# ...                   ...   ...   ...
# 2020-01-04 23:20:00   NaN   NaN   NaN
# 2020-01-04 23:30:00   NaN   NaN   NaN
# 2020-01-04 23:40:00   NaN   NaN   NaN
# 2020-01-04 23:50:00   NaN   NaN   NaN
# 2020-01-05 00:00:00  45.0  48.0  52.0
#
# [577 rows x 3 columns]

# %%
from pandas import Series, DataFrame

# %%
df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_format='%Y-%m-%d %I-%p')
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.shape
# Out:
# (23674, 7)

# %%
df.loc[::7, 'High'] = np.nan
df.loc[::6, 'Low'] = np.nan

# %%
df.head(50)
# Out:
#                   Date  Symbol    Open    High     Low   Close       Volume
# 0  2020-03-13 20:00:00  ETHUSD  129.94     NaN     NaN  128.71   1940673.93
# 1  2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2  2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 3  2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 4  2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 5  2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 6  2020-03-13 14:00:00  ETHUSD  134.03  137.90     NaN  128.39   3733916.89
# 7  2020-03-13 13:00:00  ETHUSD  131.35     NaN  128.99  134.03   9582732.93
# 8  2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 9  2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 10 2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# ...

# %%
df[['High', 'Low']].mean()
# Out:
# High    327.305205
# Low     322.276309
# dtype: float64

# %%
df[['High', 'Low']].fillna(df[['High', 'Low']].mean())
# Out:
#              High         Low
# 0      327.305205  322.276309
# 1      132.020000  117.100000
# 2      124.850000  115.500000
# 3      127.420000  121.630000
# 4      129.510000  120.170000
# ...           ...         ...
# 23669  272.740000  265.000000
# 23670  269.900000  322.276309
# 23671  274.930000  265.000000
# 23672  275.010000  271.000000
# 23673  279.990000  272.100000
#
# [23674 rows x 2 columns]

# %%
df.loc[::4, 'High'] = np.nan
df.loc[::3, 'Low'] = np.nan
df.head(50)
# Out:
#                   Date  Symbol    Open    High     Low   Close       Volume
# 0  2020-03-13 20:00:00  ETHUSD  129.94     NaN     NaN  128.71   1940673.93
# 1  2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2  2020-03-13 18:00:00  ETHUSD  124.47  124.85     NaN  119.51   4898735.81
# 3  2020-03-13 17:00:00  ETHUSD  124.08     NaN     NaN  124.47   2753450.92
# 4  2020-03-13 16:00:00  ETHUSD  124.85     NaN     NaN  124.08   4461424.71
# 5  2020-03-13 15:00:00  ETHUSD  128.39     NaN  116.06  124.85   7378976.00
# 6  2020-03-13 14:00:00  ETHUSD  134.03     NaN     NaN  128.39   3733916.89
# 7  2020-03-13 13:00:00  ETHUSD  131.35     NaN  128.99  134.03   9582732.93
# 8  2020-03-13 12:00:00  ETHUSD  128.93     NaN     NaN  131.35   3906590.52
# 9  2020-03-13 11:00:00  ETHUSD  132.60     NaN     NaN  128.93   3311080.29
# 10 2020-03-13 10:00:00  ETHUSD  133.80     NaN     NaN  132.60   3483436.48
# ...

# %%
df.interpolate()
# Out:
#                      Date  Symbol    Open        High     Low   Close  \
# 0     2020-03-13 20:00:00  ETHUSD  129.94         NaN     NaN  128.71
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.020000  117.10  129.94
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.850000  116.84  119.51
# 3     2020-03-13 17:00:00  ETHUSD  124.08  126.147778  116.58  124.47
# 4     2020-03-13 16:00:00  ETHUSD  124.85  127.445556  116.32  124.08
# ...                   ...     ...     ...         ...     ...     ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.740000  265.00  272.57
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  273.835000  265.00  265.74
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.930000  265.00  268.79
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  274.930000  265.00  274.83
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  274.930000  265.00  275.01
#
#            Volume
# 0      1940673.93
# 1      7579741.09
# 2      4898735.81
# 3      2753450.92
# 4      4461424.71
# ...

# %%
df.set_index('Date', inplace=True)
df
# Out:
#                      Symbol    Open    High    Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94     NaN    NaN  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.1  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85    NaN  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08     NaN    NaN  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85     NaN    NaN  124.08  4461424.71
# ...                     ...     ...     ...    ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79     NaN    NaN  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01     NaN    NaN  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98     NaN    NaN  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df.between_time('16:00', '18:00')
# Out:
#                      Symbol    Open    High  Low   Close      Volume
# Date
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  NaN  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08     NaN  NaN  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85     NaN  NaN  124.08  4461424.71
# 2020-03-12 18:00:00  ETHUSD  141.80  143.00  NaN  137.04  2516644.89
# 2020-03-12 17:00:00  ETHUSD  139.25     NaN  NaN  141.80  5055228.41
# ...                     ...     ...     ...  ...     ...         ...
# 2017-07-02 17:00:00  ETHUSD  271.92     NaN  NaN  281.00  7081816.11
# 2017-07-02 16:00:00  ETHUSD  267.39     NaN  NaN  271.92  2682458.25
# 2017-07-01 18:00:00  ETHUSD  263.51  266.73  NaN  259.50  5396852.35
# 2017-07-01 17:00:00  ETHUSD  268.00     NaN  NaN  263.51  1894983.33
# 2017-07-01 16:00:00  ETHUSD  272.57     NaN  NaN  268.00  1287300.75
#
# [2961 rows x 6 columns]

# %%
df.at_time('20:00')
# Out:
#                      Symbol    Open  High  Low   Close       Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94   NaN  NaN  128.71   1940673.93
# 2020-03-12 20:00:00  ETHUSD  138.00   NaN  NaN  128.15  19731142.71
# 2020-03-11 20:00:00  ETHUSD  190.09   NaN  NaN  193.37   3739916.02
# 2020-03-10 20:00:00  ETHUSD  202.26   NaN  NaN  203.12   2070524.52
# 2020-03-09 20:00:00  ETHUSD  197.61   NaN  NaN  198.34   2351877.08
# ...                     ...     ...   ...  ...     ...          ...
# 2017-07-05 20:00:00  ETHUSD  270.00   NaN  NaN  265.20   1666163.15
# 2017-07-04 20:00:00  ETHUSD  269.03   NaN  NaN  269.57    890947.64
# 2017-07-03 20:00:00  ETHUSD  278.59   NaN  NaN  279.50    765140.32
# 2017-07-02 20:00:00  ETHUSD  280.50   NaN  NaN  282.30   1436077.16
# 2017-07-01 20:00:00  ETHUSD  258.49   NaN  NaN  258.17   2366698.50
#
# [987 rows x 6 columns]

# %%
df.index = df.index.tz_convert('Asia/Kolkata')

# %%
df
# Out:
#                            Symbol    Open    High    Low   Close      Volume
# Date
# 2020-03-14 01:30:00+05:30  ETHUSD  129.94     NaN    NaN  128.71  1940673.93
# 2020-03-14 00:30:00+05:30  ETHUSD  119.51  132.02  117.1  129.94  7579741.09
# 2020-03-13 23:30:00+05:30  ETHUSD  124.47  124.85    NaN  119.51  4898735.81
# 2020-03-13 22:30:00+05:30  ETHUSD  124.08     NaN    NaN  124.47  2753450.92
# 2020-03-13 21:30:00+05:30  ETHUSD  124.85     NaN    NaN  124.08  4461424.71
# ...                           ...     ...     ...    ...     ...         ...
# 2017-07-01 20:30:00+05:30  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 2017-07-01 19:30:00+05:30  ETHUSD  268.79     NaN    NaN  265.74  1702536.85
# 2017-07-01 18:30:00+05:30  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 2017-07-01 17:30:00+05:30  ETHUSD  275.01     NaN    NaN  274.83   824362.87
# 2017-07-01 16:30:00+05:30  ETHUSD  279.98     NaN    NaN  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
# where()

# %%
df['high_val'] = df['High'].where(df['High'] > 100)

# %%
df
# Out:
#                            Symbol    Open    High    Low   Close      Volume  \
# Date
# 2020-03-14 01:30:00+05:30  ETHUSD  129.94     NaN    NaN  128.71  1940673.93
# 2020-03-14 00:30:00+05:30  ETHUSD  119.51  132.02  117.1  129.94  7579741.09
# 2020-03-13 23:30:00+05:30  ETHUSD  124.47  124.85    NaN  119.51  4898735.81
# 2020-03-13 22:30:00+05:30  ETHUSD  124.08     NaN    NaN  124.47  2753450.92
# 2020-03-13 21:30:00+05:30  ETHUSD  124.85     NaN    NaN  124.08  4461424.71
# ...                           ...     ...     ...    ...     ...         ...
# 2017-07-01 20:30:00+05:30  ETHUSD  265.74  272.74  265.0  272.57  1500282.55
# 2017-07-01 19:30:00+05:30  ETHUSD  268.79     NaN    NaN  265.74  1702536.85
# 2017-07-01 18:30:00+05:30  ETHUSD  274.83  274.93  265.0  268.79  3010787.99
# 2017-07-01 17:30:00+05:30  ETHUSD  275.01     NaN    NaN  274.83   824362.87
# 2017-07-01 16:30:00+05:30  ETHUSD  279.98     NaN    NaN  275.01   679358.87
#
#                            high_val
# ...

# %%
df.reset_index('Date', inplace=True)

# %%
# dt accessor

# %%
df['month'] = df['Date'].dt.month
df['weekday'] = df['Date'].dt.day_name()

# %%
df
# Out:
#                            Date  Symbol    Open    High    Low   Close  \
# 0     2020-03-14 01:30:00+05:30  ETHUSD  129.94     NaN    NaN  128.71
# 1     2020-03-14 00:30:00+05:30  ETHUSD  119.51  132.02  117.1  129.94
# 2     2020-03-13 23:30:00+05:30  ETHUSD  124.47  124.85    NaN  119.51
# 3     2020-03-13 22:30:00+05:30  ETHUSD  124.08     NaN    NaN  124.47
# 4     2020-03-13 21:30:00+05:30  ETHUSD  124.85     NaN    NaN  124.08
# ...                         ...     ...     ...     ...    ...     ...
# 23669 2017-07-01 20:30:00+05:30  ETHUSD  265.74  272.74  265.0  272.57
# 23670 2017-07-01 19:30:00+05:30  ETHUSD  268.79     NaN    NaN  265.74
# 23671 2017-07-01 18:30:00+05:30  ETHUSD  274.83  274.93  265.0  268.79
# 23672 2017-07-01 17:30:00+05:30  ETHUSD  275.01     NaN    NaN  274.83
# 23673 2017-07-01 16:30:00+05:30  ETHUSD  279.98     NaN    NaN  275.01
#
#            Volume  high_val  month   weekday
# 0      1940673.93       NaN      3  Saturday
# ...

# %%
# truncate()

# %%
df.truncate(before='2019-01-01', after='2020-05-01')
# Out:
#                            Date  Symbol    Open    High     Low   Close  \
# 20190 2017-11-23 19:30:00+05:30  ETHUSD  396.82     NaN     NaN  409.99
# 20191 2017-11-23 18:30:00+05:30  ETHUSD  393.00  397.00  392.99  396.82
# 20192 2017-11-23 17:30:00+05:30  ETHUSD  399.00     NaN     NaN  393.00
# 20193 2017-11-23 16:30:00+05:30  ETHUSD  396.43     NaN     NaN  399.00
# 20194 2017-11-23 15:30:00+05:30  ETHUSD  391.85  401.69     NaN  396.43
# 20195 2017-11-23 14:30:00+05:30  ETHUSD  387.00     NaN  386.99  391.85
# 20196 2017-11-23 13:30:00+05:30  ETHUSD  381.23     NaN     NaN  387.00
# 20197 2017-11-23 12:30:00+05:30  ETHUSD  382.70  383.40  381.21  381.23
# 20198 2017-11-23 11:30:00+05:30  ETHUSD  382.54  383.40     NaN  382.70
# 20199 2017-11-23 10:30:00+05:30  ETHUSD  379.99     NaN     NaN  382.54
#
#             Volume  high_val  month   weekday
# 20190  13918098.39       NaN     11  Thursday
# 20191   1941648.74    397.00     11  Thursday
# ...
