# %%
import pandas as pd

# %%
df = pd.read_csv('ETH_1h.csv', parse_dates=['Date'], date_format='%Y-%m-%d %I-%p')

# %%
df.head()
# Out:
#                  Date  Symbol    Open    High     Low   Close      Volume
# 0 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71

# %%
pd.date_range(start='2024-01-01', end='2025-01-01')
# Out:
# DatetimeIndex(['2024-01-01', '2024-01-02', '2024-01-03', '2024-01-04',
#                '2024-01-05', '2024-01-06', '2024-01-07', '2024-01-08',
#                '2024-01-09', '2024-01-10',
#                ...
#                '2024-12-23', '2024-12-24', '2024-12-25', '2024-12-26',
#                '2024-12-27', '2024-12-28', '2024-12-29', '2024-12-30',
#                '2024-12-31', '2025-01-01'],
#               dtype='datetime64[ns]', length=367, freq='D')

# %%
pd.date_range(start='2024-01-01', end='2025-01-01', freq='6T') #T is minute offset
# Out:
# DatetimeIndex(['2024-01-01 00:00:00', '2024-01-01 00:06:00',
#                '2024-01-01 00:12:00', '2024-01-01 00:18:00',
#                '2024-01-01 00:24:00', '2024-01-01 00:30:00',
#                '2024-01-01 00:36:00', '2024-01-01 00:42:00',
#                '2024-01-01 00:48:00', '2024-01-01 00:54:00',
#                ...
#                '2024-12-31 23:06:00', '2024-12-31 23:12:00',
#                '2024-12-31 23:18:00', '2024-12-31 23:24:00',
#                '2024-12-31 23:30:00', '2024-12-31 23:36:00',
#                '2024-12-31 23:42:00', '2024-12-31 23:48:00',
#                '2024-12-31 23:54:00', '2025-01-01 00:00:00'],
#               dtype='datetime64[ns]', length=87841, freq='6T')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='Y')
# Out:
# DatetimeIndex(['2020-12-31', '2021-12-31', '2022-12-31', '2023-12-31',
#                '2024-12-31', '2025-12-31', '2026-12-31', '2027-12-31',
#                '2028-12-31', '2029-12-31'],
#               dtype='datetime64[ns]', freq='A-DEC')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='M')
# Out:
# DatetimeIndex(['2020-01-31', '2020-02-29', '2020-03-31', '2020-04-30',
#                '2020-05-31', '2020-06-30', '2020-07-31', '2020-08-31',
#                '2020-09-30', '2020-10-31'],
#               dtype='datetime64[ns]', freq='M')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='W')
# Out:
# DatetimeIndex(['2020-01-05', '2020-01-12', '2020-01-19', '2020-01-26',
#                '2020-02-02', '2020-02-09', '2020-02-16', '2020-02-23',
#                '2020-03-01', '2020-03-08'],
#               dtype='datetime64[ns]', freq='W-SUN')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='D')
# Out:
# DatetimeIndex(['2020-01-01', '2020-01-02', '2020-01-03', '2020-01-04',
#                '2020-01-05', '2020-01-06', '2020-01-07', '2020-01-08',
#                '2020-01-09', '2020-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='H')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 01:00:00',
#                '2020-01-01 02:00:00', '2020-01-01 03:00:00',
#                '2020-01-01 04:00:00', '2020-01-01 05:00:00',
#                '2020-01-01 06:00:00', '2020-01-01 07:00:00',
#                '2020-01-01 08:00:00', '2020-01-01 09:00:00'],
#               dtype='datetime64[ns]', freq='H')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='s')
# Out:
# DatetimeIndex(['2020-01-01 00:00:00', '2020-01-01 00:00:01',
#                '2020-01-01 00:00:02', '2020-01-01 00:00:03',
#                '2020-01-01 00:00:04', '2020-01-01 00:00:05',
#                '2020-01-01 00:00:06', '2020-01-01 00:00:07',
#                '2020-01-01 00:00:08', '2020-01-01 00:00:09'],
#               dtype='datetime64[ns]', freq='S')

# %%
pd.date_range(start='2020-01-01', periods=10, freq='ms')
# Out:
# DatetimeIndex([       '2020-01-01 00:00:00', '2020-01-01 00:00:00.001000',
#                '2020-01-01 00:00:00.002000', '2020-01-01 00:00:00.003000',
#                '2020-01-01 00:00:00.004000', '2020-01-01 00:00:00.005000',
#                '2020-01-01 00:00:00.006000', '2020-01-01 00:00:00.007000',
#                '2020-01-01 00:00:00.008000', '2020-01-01 00:00:00.009000'],
#               dtype='datetime64[ns]', freq='L')

# %%
ser = pd.Series([
    'My date is 12202410',
    'My date is 09202328',
    'My date is 11202116',
    'My date is 05201906'
])
ser
# Out:
# 0    My date is 12202410
# 1    My date is 09202328
# 2    My date is 11202116
# 3    My date is 05201906
# dtype: object

# %%
s = pd.to_datetime(ser, format='My date is %m%Y%d')
s
# Out:
# 0   2024-12-10
# 1   2023-09-28
# 2   2021-11-16
# 3   2019-05-06
# dtype: datetime64[ns]

# %%
s = pd.to_datetime(20365, unit='D', origin='unix')
s
# Out:
# Timestamp('2025-10-04 00:00:00')

# %%
pd.to_datetime(20365, unit='D', origin='2025-01-10')
# Out:
# Timestamp('2080-10-13 00:00:00')

# %%
#set_index

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df.reset_index('Date', inplace=True)

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
ser = pd.Series([
    'My date is 12202410',
    'My date is 09202328',
    'My date is 11202116',
    'My date is 05201906'
])
ser
# Out:
# 0    My date is 12202410
# 1    My date is 09202328
# 2    My date is 11202116
# 3    My date is 05201906
# dtype: object

# %%
# If reset_index is applied on series the it will convert it into DF

# %%
ser.reset_index()
# Out:
#    index                    0
# 0      0  My date is 12202410
# 1      1  My date is 09202328
# 2      2  My date is 11202116
# 3      3  My date is 05201906

# %%
# creating new df

# %%
index = pd.date_range('2/1/2025', periods=10, freq='T') #T is minute

# %%
new_df = pd.DataFrame(data=range(10), index=index, columns=['count'])

# %%
new_df
# Out:
#                      count
# 2025-02-01 00:00:00      0
# 2025-02-01 00:01:00      1
# 2025-02-01 00:02:00      2
# 2025-02-01 00:03:00      3
# 2025-02-01 00:04:00      4
# 2025-02-01 00:05:00      5
# 2025-02-01 00:06:00      6
# 2025-02-01 00:07:00      7
# 2025-02-01 00:08:00      8
# 2025-02-01 00:09:00      9

# %%
new_df.resample('M').mean()
# Out:
#             count
# 2025-02-28    4.5

# %%
new_df.resample('M').min()
# Out:
#             count
# 2025-02-28      0

# %%
new_df.resample('2T').min()
# Out:
#                      count
# 2025-02-01 00:00:00      0
# 2025-02-01 00:02:00      2
# 2025-02-01 00:04:00      4
# 2025-02-01 00:06:00      6
# 2025-02-01 00:08:00      8

# %%
new_df.resample('5T').min()
# Out:
#                      count
# 2025-02-01 00:00:00      0
# 2025-02-01 00:05:00      5

# %%
new_df.resample('5T').sum()
# Out:
#                      count
# 2025-02-01 00:00:00     10
# 2025-02-01 00:05:00     35

# %%
new_df.resample('5T', closed='right').sum()
# Out:
#                      count
# 2025-01-31 23:55:00      0
# 2025-02-01 00:00:00     15
# 2025-02-01 00:05:00     30

# %%
new_df.resample('5T', closed='right', label='right').sum()
# Out:
#                      count
# 2025-02-01 00:00:00      0
# 2025-02-01 00:05:00     15
# 2025-02-01 00:10:00     30

# %%
index = pd.period_range('2/1/2025', periods=3, freq='Q') #Q is quarterly 
ndf = pd.DataFrame(data=range(1, 4), index=index, columns=['count'])
# ndf = pd.DataFrame(data=index)
ndf
# Out:
#         count
# 2025Q1      1
# 2025Q2      2
# 2025Q3      3

# %%
ndf.resample('M', convention='start').sum()
# Out:
#          count
# 2025-01    1.0
# 2025-02    NaN
# 2025-03    NaN
# 2025-04    2.0
# 2025-05    NaN
# 2025-06    NaN
# 2025-07    3.0
# 2025-08    NaN
# 2025-09    NaN

# %%
ndf.resample('M', convention='end').sum()
# Out:
#          count
# 2025-03    1.0
# 2025-04    NaN
# 2025-05    NaN
# 2025-06    2.0
# 2025-07    NaN
# 2025-08    NaN
# 2025-09    3.0

# %%
new_df.resample('5T', closed='right', label='right').min()
# Out:
#                      count
# 2025-02-01 00:00:00      0
# 2025-02-01 00:05:00      1
# 2025-02-01 00:10:00      6

# %%
new_df.resample('5T').max()
# Out:
#                      count
# 2025-02-01 00:00:00      4
# 2025-02-01 00:05:00      9

# %%
new_df.resample('10T').sum()
# Out:
#             count
# 2025-02-01     45

# %%
df
# Out:
#                      Date  Symbol    Open    High     Low   Close      Volume
# 0     2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 1     2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2     2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 3     2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 4     2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                   ...     ...     ...     ...     ...     ...         ...
# 23669 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 23670 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 23671 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 23672 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 23673 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 7 columns]

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#                      Symbol    Open    High     Low   Close      Volume
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71  1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94  7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51  4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47  2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08  4461424.71
# ...                     ...     ...     ...     ...     ...         ...
# 2017-07-01 15:00:00  ETHUSD  265.74  272.74  265.00  272.57  1500282.55
# 2017-07-01 14:00:00  ETHUSD  268.79  269.90  265.00  265.74  1702536.85
# 2017-07-01 13:00:00  ETHUSD  274.83  274.93  265.00  268.79  3010787.99
# 2017-07-01 12:00:00  ETHUSD  275.01  275.01  271.00  274.83   824362.87
# 2017-07-01 11:00:00  ETHUSD  279.98  279.99  272.10  275.01   679358.87
#
# [23674 rows x 6 columns]

# %%
df['7D'] = df['Close'].rolling(7).mean()
df.head(20)
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# 2020-03-13 09:00:00  ETHUSD  127.12  136.53  126.62  133.80   2767584.44
# ...

# %%
# Rolling

# %%
df['15D'] = df['Close'].rolling(15).mean()
df.head(20)
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# 2020-03-13 09:00:00  ETHUSD  127.12  136.53  126.62  133.80   2767584.44
# ...

# %%
agg_rolling = df.rolling(7).agg({'High':'max', 'Low': 'min'})
agg_rolling.head(20)
# Out:
#                        High     Low
# Date
# 2020-03-13 20:00:00     NaN     NaN
# 2020-03-13 19:00:00     NaN     NaN
# 2020-03-13 18:00:00     NaN     NaN
# 2020-03-13 17:00:00     NaN     NaN
# 2020-03-13 16:00:00     NaN     NaN
# 2020-03-13 15:00:00     NaN     NaN
# 2020-03-13 14:00:00  137.90  115.50
# 2020-03-13 13:00:00  140.95  115.50
# 2020-03-13 12:00:00  140.95  115.50
# 2020-03-13 11:00:00  140.95  116.06
# 2020-03-13 10:00:00  140.95  116.06
# 2020-03-13 09:00:00  140.95  116.06
# 2020-03-13 08:00:00  140.95  121.94
# 2020-03-13 07:00:00  140.95  120.83
# 2020-03-13 06:00:00  136.53  114.45
# 2020-03-13 05:00:00  136.53  110.75
# 2020-03-13 04:00:00  136.53  106.43
# 2020-03-13 03:00:00  148.00  106.43
# 2020-03-13 02:00:00  148.00   90.00
# 2020-03-13 01:00:00  148.00   90.00

# %%
df['rolling_mean'] = df['Close'].rolling(window=7).mean()
df.head(20)
# Out:
#                      Symbol    Open    High     Low   Close       Volume  \
# Date
# 2020-03-13 20:00:00  ETHUSD  129.94  131.82  126.87  128.71   1940673.93
# 2020-03-13 19:00:00  ETHUSD  119.51  132.02  117.10  129.94   7579741.09
# 2020-03-13 18:00:00  ETHUSD  124.47  124.85  115.50  119.51   4898735.81
# 2020-03-13 17:00:00  ETHUSD  124.08  127.42  121.63  124.47   2753450.92
# 2020-03-13 16:00:00  ETHUSD  124.85  129.51  120.17  124.08   4461424.71
# 2020-03-13 15:00:00  ETHUSD  128.39  128.90  116.06  124.85   7378976.00
# 2020-03-13 14:00:00  ETHUSD  134.03  137.90  125.50  128.39   3733916.89
# 2020-03-13 13:00:00  ETHUSD  131.35  140.95  128.99  134.03   9582732.93
# 2020-03-13 12:00:00  ETHUSD  128.93  134.60  126.95  131.35   3906590.52
# 2020-03-13 11:00:00  ETHUSD  132.60  133.17  126.01  128.93   3311080.29
# 2020-03-13 10:00:00  ETHUSD  133.80  134.99  128.90  132.60   3483436.48
# 2020-03-13 09:00:00  ETHUSD  127.12  136.53  126.62  133.80   2767584.44
# ...

# %%
# Shift

# %%
shift_df = pd.DataFrame({"Col1": [10, 20, 15, 30, 45],
                   "Col2": [13, 23, 18, 33, 48],
                   "Col3": [17, 27, 22, 37, 52]},
                  index=pd.date_range("2020-01-01", "2020-01-05"))
shift_df
# Out:
#             Col1  Col2  Col3
# 2020-01-01    10    13    17
# 2020-01-02    20    23    27
# 2020-01-03    15    18    22
# 2020-01-04    30    33    37
# 2020-01-05    45    48    52

# %%
shift_df.shift(3)
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN   NaN   NaN
# 2020-01-02   NaN   NaN   NaN
# 2020-01-03   NaN   NaN   NaN
# 2020-01-04  10.0  13.0  17.0
# 2020-01-05  20.0  23.0  27.0

# %%
shift_df.shift(1, axis="columns")
# Out:
#             Col1  Col2  Col3
# 2020-01-01   NaN    10    13
# 2020-01-02   NaN    20    23
# 2020-01-03   NaN    15    18
# 2020-01-04   NaN    30    33
# 2020-01-05   NaN    45    48

# %%
shift_df.shift(1, fill_value='empty')
# Out:
#              Col1   Col2   Col3
# 2020-01-01  empty  empty  empty
# 2020-01-02     10     13     17
# 2020-01-03     20     23     27
# 2020-01-04     15     18     22
# 2020-01-05     30     33     37

# %%
shift_df.shift(1, fill_value='Empty', axis='columns')
# Out:
#              Col1  Col2  Col3
# 2020-01-01  Empty    10    13
# 2020-01-02  Empty    20    23
# 2020-01-03  Empty    15    18
# 2020-01-04  Empty    30    33
# 2020-01-05  Empty    45    48

# %%
shift_df.shift(1, freq='D')
# Out:
#             Col1  Col2  Col3
# 2020-01-02    10    13    17
# 2020-01-03    20    23    27
# 2020-01-04    15    18    22
# 2020-01-05    30    33    37
# 2020-01-06    45    48    52

# %%
shift_df.shift(1, freq='T')
# Out:
#                      Col1  Col2  Col3
# 2020-01-01 00:01:00    10    13    17
# 2020-01-02 00:01:00    20    23    27
# 2020-01-03 00:01:00    15    18    22
# 2020-01-04 00:01:00    30    33    37
# 2020-01-05 00:01:00    45    48    52

# %%
shift_df.shift(1, freq='5T')
# Out:
#                      Col1  Col2  Col3
# 2020-01-01 00:05:00    10    13    17
# 2020-01-02 00:05:00    20    23    27
# 2020-01-03 00:05:00    15    18    22
# 2020-01-04 00:05:00    30    33    37
# 2020-01-05 00:05:00    45    48    52

# %%
shift_df.shift(3, freq='Y')
# Out:
#             Col1  Col2  Col3
# 2022-12-31    10    13    17
# 2022-12-31    20    23    27
# 2022-12-31    15    18    22
# 2022-12-31    30    33    37
# 2022-12-31    45    48    52

# %%
shift_df.shift(3, freq='infer')
# Out:
#             Col1  Col2  Col3
# 2020-01-04    10    13    17
# 2020-01-05    20    23    27
# 2020-01-06    15    18    22
# 2020-01-07    30    33    37
# 2020-01-08    45    48    52

# %%
shift_df['Col3'].shift(3, freq='infer', axis='index')
# Out:
# 2020-01-04    17
# 2020-01-05    27
# 2020-01-06    22
# 2020-01-07    37
# 2020-01-08    52
# Freq: D, Name: Col3, dtype: int64

# %%
df_sh= shift_df['Col3'].shift(3, freq='D').reset_index()
df_sh.set_index('index', inplace=True)
df_sh
# Out:
#             Col3
# index
# 2020-01-04    17
# 2020-01-05    27
# 2020-01-06    22
# 2020-01-07    37
# 2020-01-08    52

# %%
df_sh.shift(, freq='D', axis='index')
# Out:
#             Col3
# index
# 2020-01-07    17
# 2020-01-08    27
# 2020-01-09    22
# 2020-01-10    37
# 2020-01-11    52

# %%
shift_df['Col4'] = shift_df['Col1'].shift(1)

# %%
shift_df
# Out:
#             Col1  Col2  Col3  Col4
# 2020-01-01    10    13    17   NaN
# 2020-01-02    20    23    27  10.0
# 2020-01-03    15    18    22  20.0
# 2020-01-04    30    33    37  15.0
# 2020-01-05    45    48    52  30.0
